# %% [markdown]
# <a href="https://colab.research.google.com/github/ericgbraz/COLAB_PED/blob/main/PED_Aula_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

cep = input('Digite seu cep ')
res = requests.get('https://cep.awesomeapi.com.br/json/'+cep.replace('-',''))
dict_json = res.json()
dict_json[('cep')]
# Out:
# Digite seu cep 05128190
# '05128190'

# %%
import requests
url = 'https://viacep.com.br/ws/'
lista_ceps = ['30140071','30140072', '30140073', '30140074', 
'30140075','30140076']
formato = '/json/'
for cep in lista_ceps:
 r = requests.get(url + cep + formato)
 if (r):
  print()
  print('CEP : ', cep)
  print('JSON : ', r.text)
  print()
 else:
  print('Nao houve sucesso na requisicao.')
# Out:
# CEP :  30140071
# JSON :  {
#   "cep": "30140-071",
#   "logradouro": "Rua dos Aimorés",
#   "complemento": "de 971/972 a 1399/1400",
#   "bairro": "Boa Viagem",
#   "localidade": "Belo Horizonte",
#   "uf": "MG",
#   "ibge": "3106200",
#   "gia": "",
#   "ddd": "31",
#   "siafi": "4123"
# }
#
#
# CEP :  30140072
# JSON :  {
#   "cep": "30140-072",
#   "logradouro": "Rua dos Aimorés",
#   "complemento": "de 1401/1402 a 1799/1800",
#   "bairro": "Lourdes",
#   "localidade": "Belo Horizonte",
#   "uf": "MG",
#   "ibge": "3106200",
#   "gia": "",
#   "ddd": "31",
#   "siafi": "4123"
# }
#
#
# CEP :  30140073
# JSON :  {
#   "cep": "30140-073",
#   "logradouro": "Rua dos Aimorés",
#   "complemento": "de 2761/2762 a 3299/3300",
#   "bairro": "Barro Preto",
#   "localidade": "Belo Horizonte",
#   "uf": "MG",
#   "ibge": "3106200",
#   "gia": "",
#   "ddd": "31",
#   "siafi": "4123"
# }
#
#
# CEP :  30140074
# JSON :  {
#   "cep": "30140-074",
#   "logradouro": "Rua dos Aimorés",
# ...

# %%
import requests
url = 'https://viacep.com.br/ws/'
lista_ceps = ['05128190','30140072', '30140073', '30140075', '30140075','30140076']
formato = '/json/'

lista_json = []

for cep in lista_ceps:
 r = requests.get(url + cep + formato)
 if (r):
  lista_json.append(r.json())
 else:
  print('Nao houve sucesso na requisicao.')

df = pd.DataFrame(lista_json)
df
# Out:
#          cep                logradouro               complemento  \
# 0  05128-190  Rua Edvard de Vita Godoy
# 1  30140-072           Rua dos Aimorés  de 1401/1402 a 1799/1800
# 2  30140-073           Rua dos Aimorés  de 2761/2762 a 3299/3300
# 3  30140-075           Rua dos Aimorés      de 531/532 a 969/970
# 4  30140-075           Rua dos Aimorés      de 531/532 a 969/970
# 5  30140-076           Rua dos Aimorés  de 2371/2372 a 2759/2760
#
#                   bairro      localidade  uf     ibge   gia ddd siafi
# 0  Parque Maria Domitila       São Paulo  SP  3550308  1004  11  7107
# 1                Lourdes  Belo Horizonte  MG  3106200        31  4123
# 2            Barro Preto  Belo Horizonte  MG  3106200        31  4123
# 3           Funcionários  Belo Horizonte  MG  3106200        31  4123
# 4           Funcionários  Belo Horizonte  MG  3106200        31  4123
# 5        Santo Agostinho  Belo Horizonte  MG  3106200        31  4123

# %%
import requests
import pandas as pd

res = requests.get('https://api.sampleapis.com/presidents/presidents')

df = pd.DataFrame(res.json())
df[['inicio', 'fim']] = df.yearsInOffice.str.split('-', expand = True)
df
df_vice = df.explode('vicePresidents')[['name','vicePresidents']]
df_vice
# Out:
#                       name          vicePresidents
# 0        George Washington              John Adams
# 1               John Adams        Thomas Jefferson
# 2         Thomas Jefferson              Aaron Burr
# 2         Thomas Jefferson          George Clinton
# 3            James Madison          George Clinton
# 3            James Madison          Elbridge Gerry
# 4             James Monroe      Daniel D. Tompkins
# 5        John Quincy Adams         John C. Calhoun
# 6           Andrew Jackson         John C. Calhoun
# 6           Andrew Jackson        Martin Van Buren
# 7         Martin Van Buren  Richard Mentor Johnson
# 8   William Henry Harrison              John Tyler
# 9               John Tyler                    None
# 10           James K. Polk        George M. Dallas
# 11           Zacary Taylor        Millard Fillmore
# 12        Millard Fillmore                    None
# 13         Franklin Pierce         William R. King
# ...

# %%
import requests

res = requests.get('https://economia.awesomeapi.com.br/last/USD-BRL,EUR-BRL,BTC-BRL')

cotacoes  = res.json()

print(cotacoes)
print(cotacoes['USDBRL']['bid'])
# Out:
# {'USDBRL': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '4.9674', 'low': '4.9665', 'varBid': '0.0007', 'pctChange': '0.01', 'bid': '4.9669', 'ask': '4.9679', 'timestamp': '1684801997', 'create_date': '2023-05-22 21:33:17'}, 'EURBRL': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '5.374', 'low': '5.3693', 'varBid': '0.0002', 'pctChange': '0', 'bid': '5.3687', 'ask': '5.3767', 'timestamp': '1684802000', 'create_date': '2023-05-22 21:33:20'}, 'BTCBRL': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '135045', 'low': '133289', 'varBid': '-75', 'pctChange': '-0.06', 'bid': '134102', 'ask': '134152', 'timestamp': '1684802004', 'create_date': '2023-05-22 21:33:24'}}
# 4.9669

# %%
import requests
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np

res = requests.get('https://economia.awesomeapi.com.br/json/daily/USD-BRL/30')

cotacoes  = res.json()

# %%
df = pd.DataFrame(cotacoes)

df['bid'] = pd.to_numeric(df['bid'])
df['data'] = pd.to_datetime(df['timestamp'], unit ='s')

plt.ylabel("Cotação")
plt.xlabel("Data")
plt.xticks(rotation = 'vertical')

plt.plot(df['data'], df['bid']);
